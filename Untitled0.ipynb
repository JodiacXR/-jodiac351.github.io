# %% [markdown]
# <a href="https://colab.research.google.com/github/JodiacXR/-jodiac351.github.io/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile order.py
def process_order(member, amount, coupon, express, international,
                  fragile, insured, weekend, gift_wrap, priority,
                  bulk_order, tax_exempt):
    messages = []

    if not isinstance(amount, (int, float)):
        messages.append("Error: 'amount' must be a number.")
        messages.append("Order processing halted due to invalid amount.")
        return messages # Early exit if amount is invalid

    if member:
        messages.append("Member discount applied")

    if amount > 100:
        messages.append("Large order")

    if coupon:
        messages.append("Coupon used")

    if express:
        messages.append("Express shipping")

    if international:
        messages.append("International shipment")

    if fragile:
        messages.append("Fragile item")

    if insured:
        messages.append("Insurance added")

    if weekend:
        messages.append("Weekend processing")

    if gift_wrap:
        messages.append("Gift wrapping selected")

    if priority:
        messages.append("Priority handling")

    if bulk_order:
        messages.append("Bulk order discount")

    if tax_exempt:
        messages.append("Tax exempt order")

    messages.append("Order processed")
    return messages

# Test the function to demonstrate 13 outputs
import importlib
import order

# Reload the module to ensure changes are picked up
importlib.reload(order)

# Set all 12 conditional flags to True, and amount > 100 for 'Large order'
# This will result in 12 conditional messages + 1 'Order processed' = 13 messages.
test_messages = order.process_order(
    member=True, amount=150, coupon=True, express=True, international=True,
    fragile=True, insured=True, weekend=True, gift_wrap=True, priority=True,
    bulk_order=True, tax_exempt=True
)
print(f"Number of messages: {len(test_messages)}")
print("Messages:")
for msg in test_messages:
    print(msg)
# Out:
# Overwriting order.py

# %%
# %%writefile order.py
def process_order(member, amount, coupon, express, international,
                  fragile, insured, weekend, gift_wrap, priority,
                  bulk_order, tax_exempt):
    messages = []

    if not isinstance(amount, (int, float)):
        messages.append("Error: 'amount' must be a number.")
        messages.append("Order processing halted due to invalid amount.")
        return messages # Early exit if amount is invalid

    if member:
        messages.append("Member discount applied")

    if amount > 100:
        messages.append("Large order")

    if coupon:
        messages.append("Coupon used")

    if express:
        messages.append("Express shipping")

    if international:
        messages.append("International shipment")

    if fragile:
        messages.append("Fragile item")

    if insured:
        messages.append("Insurance added")

    if weekend:
        messages.append("Weekend processing")

    if gift_wrap:
        messages.append("Gift wrapping selected")

    if priority:
        messages.append("Priority handling")

    if bulk_order:
        messages.append("Bulk order discount")

    if tax_exempt:
        messages.append("Tax exempt order")

    messages.append("Order processed")
    return messages

# Import the updated module
import importlib
import order

# Reload the module to ensure changes are picked up
importlib.reload(order)

print("--- Testing valid order (large, member, express, fragile, insured, priority) ---")
valid_order_messages = order.process_order(
    member=True, amount=150, coupon=False, express=True, international=False,
    fragile=True, insured=True, weekend=False, gift_wrap=False, priority=True,
    bulk_order=False, tax_exempt=False
)
for msg in valid_order_messages:
    print(msg)

print("\n--- Testing order with invalid amount (should halt processing early) ---")
invalid_amount_order_messages = order.process_order(
    member=True, amount="200", coupon=False, express=True, international=False,
    fragile=True, insured=True, weekend=False, gift_wrap=False, priority=True,
    bulk_order=False, tax_exempt=False
)
for msg in invalid_amount_order_messages:
    print(msg)

print("\n--- Testing another valid order (small, coupon, international, weekend, gift_wrap, bulk_order, tax_exempt) ---")
another_valid_order_messages = order.process_order(
    member=False, amount=50, coupon=True, express=False, international=True,
    fragile=False, insured=False, weekend=True, gift_wrap=True, priority=False,
    bulk_order=True, tax_exempt=True
)
for msg in another_valid_order_messages:
    print(msg)
# Out:
# Overwriting order.py
